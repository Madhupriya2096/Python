# %%
25
# Out:
# 25

# %%
int(25)
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25) #number to octal number system
# Out:
# '0o31'

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(2)
# Out:
# '0x2'

# %%
hex(8)
# Out:
# '0x8'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(11)
# Out:
# '0xb'

# %%
hex(12)
# Out:
# '0xc'

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %%
int(0x19)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25
