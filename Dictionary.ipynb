# %% [markdown]
# #####DICTIONARY

# %%
mydict = dict() #empty dictionary
mydict
# Out:
# {}

# %%
mydict ={}  #empty dictionary
mydict
# Out:
# {}

# %%
type(d)
# Out:
# dict

# %%
d[3] = 'three'
d
# Out:
# {'4': [100, 200, 300],
#  '1': [100, 200, 300],
#  '2': [100, 200, 300],
#  '3': [100, 200, 300],
#  3: 'three'}

# %%
d = {1:'one', 2:'two'}  #dictionary with integer keys
d
# Out:
# {1: 'one', 2: 'two'}

# %%
d = dict({1:'one',2: 'two',3:'three'})    # Create dictionary using dict()
d
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d1 = {'A':'one', 'B':'two', 'C':'three'}  # dictionary with character keys
d1
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
d2 ={5:'one', 'A':'two', 3:'three'}   # dictionary with mixed keys 
d2
# Out:
# {5: 'one', 'A': 'two', 3: 'three'}

# %%
d.keys()     # Return Dictionary Keys using keys() method
# Out:
# dict_keys([1, 2, 3])

# %%
d.values()    # Return Dictionary Values using values() method
# Out:
# dict_values(['one', 'two', 'three'])

# %%
d1.items()    # Access each key-value pair within a dictionary
# Out:
# dict_items([('A', 'one'), ('B', 'two'), ('C', 'three')])

# %%
d={1:'one', 2:'two', 'A':['madhu', 'priya','sai']}
d
# Out:
# {1: 'one', 2: 'two', 'A': ['madhu', 'priya', 'sai']}

# %%
d={1:'one', 2:'two', 'A':{'Name': 'madhu', 'Place': 'Hyd'}, 'B':('Mat','Cat','Lion')}
d
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'madhu', 'Place': 'Hyd'},
#  'B': ('Mat', 'Cat', 'Lion')}

# %%
keys={'1','2','3','4'}
d=dict.fromkeys(keys)    # Create a dictionary from a sequence of keys 
d
# Out:
# {'4': None, '1': None, '2': None, '3': None}

# %%
keys={'1','2','3','4'}
value = 10
d=dict.fromkeys(keys,value)    # Create a dictionary from a sequence of keys &value
d
# Out:
# {'4': 10, '1': 10, '2': 10, '3': 10}

# %%
keys={'1','2','3','4'}
value = [100,200,300]
d=dict.fromkeys(keys,value)    # Create a dictionary from a sequence of keys &value
d
# Out:
# {'4': [100, 200, 300],
#  '1': [100, 200, 300],
#  '2': [100, 200, 300],
#  '3': [100, 200, 300]}

# %% [markdown]
# ####ACCESSING ITEMS

# %%
d = dict({1:'one',2: 'two',3:'three'})  
d
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d[1]       # Access item using get() method
# Out:
# 'one'

# %%
d1 = {'Name': 'Madhu', 'ID': 201365, 'DOB': 2023, 'job': 'Associate'}
d1
# Out:
# {'Name': 'Madhu', 'ID': 201365, 'DOB': 2023, 'job': 'Associate'}

# %%
d1['job']      # Access item using key
# Out:
# 'Associate'

# %% [markdown]
# #######ADD, REMOVE & CHANGE ITEMS

# %%
d1
# Out:
# {'Name': 'Madhu', 'ID': 201365, 'DOB': 2023, 'job': 'Associate'}

# %%
d1['DOB'] = 2025         # Changing Dictionary Items 
d1['Address'] = 'UK'
d1
# Out:
# {'Name': 'Madhu',
#  'ID': 201365,
#  'DOB': 2025,
#  'job': 'Associate',
#  'Address': 'UK'}

# %%
d2 = {'DOB':1995}        # Adding items in the dictionary 
d1.update(d2)
d1
# Out:
# {'Name': 'Madhu', 'ID': 201365, 'DOB': 1995, 'job': 'Associate'}

# %%
d1.pop('job')      # Removing items in the dictionary using Pop method
d1
# Out:
# {'Name': 'Madhu', 'ID': 201365, 'DOB': 2025, 'Address': 'UK'}

# %%
d1.popitem()     # A random item is removed
# Out:
# ('job', 'Associate')

# %%
d1
# Out:
# {'Name': 'Madhu', 'ID': 201365, 'DOB': 1995}

# %%
d1.clear()     # Delete all items of the dictionary using clear method
d1
# Out:
# {}

# %%
del d1       # Delete the dictionary object
d1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 del d1
# ----> 2 d1
#
# NameError: name 'd1' is not defined

# %% [markdown]
# #######COPY DICTIONARY

# %%
d={1:'one', 2:'two', 'A':{'Name': 'madhu', 'Place': 'Hyd'}, 'B':('Mat','Cat','Lion')}
d
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'madhu', 'Place': 'Hyd'},
#  'B': ('Mat', 'Cat', 'Lion')}

# %%
d1 =d        # Create a new reference "d1"
d
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'madhu', 'Place': 'Hyd'},
#  'B': ('Mat', 'Cat', 'Lion')}

# %%
id(d1), id(d)   # The address of both mydict & mydict1 will be the same
# Out:
# (2553084652992, 2553084652992)

# %%
d2 = d.copy()      # Create a copy of the dictionary

# %%
id(d1)     # The address of d1 will be different from d because d1
# Out:
# 2553084191808

# %%
d1['Address'] = 'Mumbai'
d1
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'madhu', 'Place': 'Hyd'},
#  'B': ('Mat', 'Cat', 'Lion'),
#  'Address': 'Mumbai'}

# %%
d
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'madhu', 'Place': 'Hyd'},
#  'B': ('Mat', 'Cat', 'Lion')}

# %%
d1       # mydict1 will be also impacted as it is pointing to the same dictionary
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'madhu', 'Place': 'Hyd'},
#  'B': ('Mat', 'Cat', 'Lion'),
#  'Address': 'Mumbai'}

# %% [markdown]
# #######RANGE

# %%
d2  # Copy of list won't be impacted due to the changes made in the original
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'madhu', 'Place': 'Hyd'},
#  'B': ('Mat', 'Cat', 'Lion')}

# %% [markdown]
# #####LOOP THROUGH A DICTIONARY

# %%
d={1:'one', 2:'two', 'A':{'Name': 'madhu', 'Place': 'Hyd'}, 'B':('Mat','Cat','Lion')}
d
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'madhu', 'Place': 'Hyd'},
#  'B': ('Mat', 'Cat', 'Lion')}

# %%
for i in d:
    print(i, ':', d[i])
# Out:
# 1 : one
# 2 : two
# A : {'Name': 'madhu', 'Place': 'Hyd'}
# B : ('Mat', 'Cat', 'Lion')

# %%
for i in d1:
    print(i, ':', d1[i])
# Out:
# 1 : one
# 2 : two
# A : {'Name': 'madhu', 'Place': 'Hyd'}
# B : ('Mat', 'Cat', 'Lion')
# Address : Mumbai

# %% [markdown]
# #####DICTIONARY MEMBERSHIP

# %%
d1 = {'Name': 'Madhu', 'ID': 201365, 'DOB': 2023, 'job': 'Associate'}
d1
# Out:
# {'Name': 'Madhu', 'ID': 201365, 'DOB': 2023, 'job': 'Associate'}

# %%
'Name' in d1   # Test if a key is in a dictionary or not.
# Out:
# True

# %%
'Madhu' in d1        # Membership test can be only done for keys.
# Out:
# False

# %% [markdown]
# #####ALL/ANY

# %%
d1d1 = {'Name': 'Madhu', 'ID': 201365, 'DOB': 2023, 'job': 'Associate'}
d1
# Out:
# {'Name': 'Madhu', 'ID': 201365, 'DOB': 2023, 'job': 'Associate'}

# %%
all(d1)   # Will Return false as one value is false (Value 0)
# Out:
# True

# %%
any(d1)
# Out:
# True
