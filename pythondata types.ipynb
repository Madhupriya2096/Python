# %%
a=1

# %%
v1=25

# %%
v=5

# %%
print(a,v1,v)
# Out:
# 1 25 5

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# INTEGER

# %%
i = 5

# %%
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140733288146168

# %%
age = 24
age
# Out:
# 24

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(id(age))
# Out:
# 140721794115416

# %% [markdown]
# FLOAT

# %%
f=200.50

# %%
print(f)
# Out:
# 200.5

# %%
type(f)
# Out:
# float

# %%
id(f)
# Out:
# 1906986330448

# %%
i = 5

# %%
print(i)
# Out:
# 5

# %%
print(f)
# Out:
# 200.5

# %% [markdown]
# BOOLEAN

# %%
b=True

# %%
b
# Out:
# True

# %%
print(b)
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
int(b)
# Out:
# 1

# %%
b1=False

# %%
b1
# Out:
# False

# %%
print(b)
# Out:
# True

# %%
type(b1)
# Out:
# bool

# %%
id(b,b1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 id(b,b1)
#
# TypeError: id() takes exactly one argument (2 given)

# %%
print(id(b))
# Out:
# 140721793200640

# %%
print(id(b1))
# Out:
# 140721793200672

# %%
p=10
q=20

# %%
p
q
# Out:
# 20

# %%
print(p,q)
# Out:
# 10 20

# %%
print(id(p))
print(id(q))
# Out:
# 140721794114968
# 140721794115288

# %%
print(b)
print(b1)
# Out:
# True
# False

# %%
b
# Out:
# True

# %%
b1
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
False+True
# Out:
# 1

# %%
True-False
# Out:
# 1

# %%
False-True
# Out:
# -1

# %%
True*False
# Out:
# 0

# %%
False*True
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
False//True
# Out:
# 0

# %% [markdown]
# COMPLEX

# %%
complex
# Out:
# complex

# %%
complex(1)
# Out:
# (1+0j)

# %%
complex(9,10)
# Out:
# (9+10j)

# %%
c=10

# %%
c
# Out:
# 10

# %%
c1=10+10j

# %%
c.real
# Out:
# 10

# %%
c.imag
# Out:
# 0

# %%
c1.imag
# Out:
# 10.0

# %%
c1.real
# Out:
# 10.0

# %%
c=10+20j
c1=20+30j

# %%
print(c,c1)
# Out:
# (10+20j) (20+30j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
type(c)
# Out:
# complex

# %% [markdown]
# STRING

# %%
str(1)
# Out:
# '1'

# %%
type(1)
# Out:
# int

# %%
s = 'welcome team'

# %%
s
# Out:
# 'welcome team'

# %%
type(s)
# Out:
# str

# %%
s= 'welcome team'

# %%
s
# Out:
# 'welcome team'

# %%
s1='welcome home'

# %%
s1
# Out:
# 'welcome home'

# %%
s2='''python course'''

# %%
s2
# Out:
# 'python course'

# %%
s4= '''welcome to home 
and feel free to have some food
feel at home'''

# %%
s4
# Out:
# 'welcome to home \nand feel free to have some food\nfeel at home'
