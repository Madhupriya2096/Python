# %% [markdown]
# FRAMEWORK

# %% [markdown]
# MATH MODULE

# %%
25
# Out:
# 25

# %%
sqrt (25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sqrt (25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
math.floor(3.5)
# Out:
# 3

# %%
math.ceil(3.5)
# Out:
# 4

# %%
import math as m
m.floor(3.4)

# %%
math.floor(4.9)
# Out:
# 4

# %%
math.ceil(4.9)
# Out:
# 5

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
m.floor(3,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 m.floor(3,4)
#
# NameError: name 'm' is not defined

# %%
import math as m
print(m.floor(3.4))
print(m.ceil(3.4))
print(m.pow(2,3))
print(m.sqrt(25))
# Out:
# 3
# 4
# 8.0
# 5.0

# %%
print(n.floor(3.4))
print(n.ceil(3.4))
print(n.pow(2,3))
print(n.sqrt(25))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(n.floor(3.4))
#       2 print(n.ceil(3.4))
#       3 print(n.pow(2,3))
#       4 print(n.sqrt(25))
#
# NameError: name 'n' is not defined

# %%
import math as n
print(n.floor(3.4))
print(n.ceil(3.4))
print(n.pow(2,3))
print(n.sqrt(25))
# Out:
# 3
# 4
# 8.0
# 5.0

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
from math import pow, floor, ceil, sqrt #it can understand only four functions
print(pow(2,3))
print(sqrt(10))
print(floor(2.3))
print(ceil(2.3))
# Out:
# 8.0
# 3.1622776601683795
# 2
# 3

# %% [markdown]
# HELP FUNCTION

# %%
help()
# Out:
# Welcome to Python 3.14's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.14/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# You can use the following keyboard shortcuts at the main interpreter prompt.
# F1: enter interactive help, F2: enter history browsing mode, F3: enter paste
# mode (press again to exit).
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  math
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
# ...

# %%
from math import pow, floor, ceil

print(pow(2,3))
print(floor(2.3))
print(ceil(2.3))
# Out:
# 8.0
# 2
# 3

# %%
from math import * #to print all math module functions

print(pow(2,3))
print(sqrt(10))
print(floor(2.3))
print(ceil(2.3))
# Out:
# 8.0
# 3.1622776601683795
# 2
# 3

# %% [markdown]
# #INPUT() FUNCTION

# %% [markdown]
# #INPUT() WITH NUMBER

# %%
x=input()
x
# Out:
#  5
# '5'

# %%
x=input()
y=input()
z=x+y
print(z)
# Out:
#  5
#  3
# 53

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x=int(input())
y=int(input())

z=x+y
print(z)
# Out:
#  5
#  3
# 8

# %% [markdown]
# INPUT() WITH STRING

# %%
st = input('enter a string')
print(st)
#print(type(ch))
# Out:
# enter a string hello
# hello

# %%
print(st[0])
# Out:
# h

# %%
print(st[0:2])
# Out:
# he

# %%
print(st[1])
# Out:
# e

# %%
print(st[-1])
# Out:
# o

# %%
st = input('enter a string')[0]
print(st)
# Out:
# enter a string hello team
# h

# %%
st=input('enter a string')[11:]
print(st)
# Out:
# enter a string 2345678900115533
# 15533

# %% [markdown]
# #INPUT() WITH EXPRESSION

# %%
result=input('enter an expr')
print(result)
# Out:
# enter an expr 2+3+5-2
# 2+3+5-2

# %%
result=eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 2+3+5-2
# 8
