# %%
first_name ='MADHU'

# %%
last_name = 'PRIYA'

# %%
country = 'United kingdom'

# %%
city = 'bristol'

# %%
age = 20

# %%
is_married = False

# %%
skills = ['python', 'CSS']

# %%
person_info = {
    'firstname':'Madhu', 
    'lastname':'Priya', 
    'country':'United kingdom',
    'city':'Bristol'
    }

# %%
# Printing the values stored in the variables

# %%
print('First name:', first_name)
# Out:
# First name: MADHU

# %%
print('First name length:', len(first_name))
# Out:
# First name length: 5

# %%
print('last name:', last_name)
# Out:
# last name: PRIYA

# %%
print('Last name length: ', len(last_name))
# Out:
# Last name length:  5

# %%
print('Country: ', country)
# Out:
# Country:  Unitedkingdom

# %%
print('City:', city)
# Out:
# City: bristol

# %%
print('Age: ', age)
# Out:
# Age:  20

# %%
print('Married: ', is_married)
# Out:
# Married:  False

# %%
print('Skills: ', skills)
# Out:
# Skills:  ['python', 'CSS']

# %%
print('Person information:' , person_info)
# Out:
# Person information: {'firstname': 'Madhu', 'lastname': 'Priya', 'country': 'United kingdom', 'city': 'Bristol'}

# %%
# Declaring multiple variable in one line

# %%
first_name, last_name, country, age, is_married = 'madhu' , 'priya', 'United Kingdom', 20, False

# %%
print(first_name, last_name, country, age, is_married)
# Out:
# madhu priya United Kingdom 20 False

# %%
print('First name:', first_name)
# Out:
# First name: madhu

# %%
print('Last name: ', last_name)
# Out:
# Last name:  priya

# %%
print('Country: ', country)
# Out:
# Country:  United Kingdom

# %%
print('Age: ', age)
# Out:
# Age:  20

# %%
print('Married: ', is_married)
# Out:
# Married:  False
