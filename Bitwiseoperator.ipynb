# %% [markdown]
# AND &

# %%
12&13
# Out:
# 12

# %% [markdown]
# OR |

# %%
12|13
# Out:
# 13

# %% [markdown]
# XCLUSIVE OR

# %%
12^13
# Out:
# 1

# %% [markdown]
# LEFT SHIFT <<

# %%
12<<2
# Out:
# 48

# %%
12<<1
# Out:
# 24

# %% [markdown]
# RIGHT SHIFT>>

# %%
12>>1
# Out:
# 6

# %%
12>>2
# Out:
# 3

# %% [markdown]
# COMPLEMENT

# %%
~1
# Out:
# -2

# %%
~12
# Out:
# -13
