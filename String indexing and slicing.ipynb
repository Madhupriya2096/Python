# %% [markdown]
# STRING INDEXES

# %%
s ='I am Madhu Priya'

# %%
s[:]
# Out:
# 'I am Madhu Priya'

# %%
s ='I am Madhu Priya'
s
# Out:
# 'I am Madhu Priya'

# %%
s[0]    # First character in string "s"
# Out:
# 'I'

# %%
s[1]    # Second character in string "s"
# Out:
# ' '

# %%
s[3]    # Third character in string "s"
# Out:
# 'm'

# %%
s[-1]    #Backward indexing
# Out:
# 'a'

# %%
s[len(s)-1]      # Last character in string using len function
# Out:
# 'a'

# %% [markdown]
# ######STRING SLICING

# %%
s
# Out:
# 'I am Madhu Priya'

# %%
s[0:5]    # String slicing - Fetch all characters from 0 to 5 index location
# Out:
# 'I am '

# %%
s[6:9]
# Out:
# 'adh'

# %% [markdown]
# ######Update & Delete String

# %%
s
# Out:
# 'I am Madhu Priya'

# %%
del[s]  #cannot delete the string as they are immutable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 del[s]
#
# NameError: name 's' is not defined

# %%
s[0:5] = 'irreplacable'  #cannot change the string as they are immutable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 s[0:5] = 'irreplacable'
#
# NameError: name 's' is not defined

# %% [markdown]
# #####String cancatenation

# %%
s1='Hello'
s2='Madhu'
s3=s1+s2
print (s3)
# Out:
# HelloMadhu
