# %% [markdown]
# #####TUPLE

# %%
t=()  #EMPTY TUPLE
t
# Out:
# ()

# %%
t1=(10,20,30)  #TUPLE WITH INTEGER
t1
# Out:
# (10, 20, 30)

# %%
t2=('madhu','priya','hyd')  #TUPLE WITH STRINGS
t2
# Out:
# ('madhu', 'priya', 'hyd')

# %%
t3=(3.5,2.5,6.1) #TUPLE WITH FLOAT
t3
# Out:
# (3.5, 2.5, 6.1)

# %%
t4=(True,False)  #TUPLE WITH BOOLEAN
t4
# Out:
# (True, False)

# %%
t5=('Madhu', 40, 3.5, [10,20,30]) #TUPLE WITH MIXED DATATYPES
t5
# Out:
# ('Madhu', 40, 3.5, [10, 20, 30])

# %%
t6=('madhu', 60, (10,20),(90,100,200))    #NESTED TUPLES
t6
# Out:
# ('madhu', 60, (10, 20), (90, 100, 200))

# %%
len(t5)  #LENGTH OF TUPLE
# Out:
# 4

# %%
type(t)
# Out:
# tuple

# %%
t1=(10, True, 2.3, 1+2j, 'welcome')
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %% [markdown]
# ####TUPLE INDEXING

# %%
t5
# Out:
# ('Madhu', 40, 3.5, [10, 20, 30])

# %%
t5[0]  #RETRIEVE FIRST ELEMENT OF THE TUPLE
# Out:
# 'Madhu'

# %%
t3[0]
# Out:
# 3.5

# %%
t2
# Out:
# ('madhu', 'priya', 'hyd')

# %%
t2[0][4] #NESTED INDEXING - access the first character og first tuple element
# Out:
# 'u'

# %%
t2[-1] #Last item of tuple
# Out:
# 'hyd'

# %% [markdown]
# #######TUPLE SLICING

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1[0:2] #return all items from 0th to 2ndindex location
# Out:
# (10, 20)

# %%
t5
# Out:
# ('Madhu', 40, 3.5, [10, 20, 30])

# %%
t5[2:5] #return all items from 2nd to 5th index
# Out:
# (3.5, [10, 20, 30])

# %%
t5[:3] #return first three items
# Out:
# ('Madhu', 40, 3.5)

# %%
t5[-3:]  #return last three items
# Out:
# (40, 3.5, [10, 20, 30])

# %%
t5[-1:]  #return last item of tuple
# Out:
# ([10, 20, 30],)

# %%
t5[:]  #return whole tuple
# Out:
# ('Madhu', 40, 3.5, [10, 20, 30])

# %% [markdown]
# #####REMOVE & CHANGE ITEMS

# %%
t1=(10, True, 2.3, 1+2j, 'welcome')
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
del t1[0]  #Tuples are immutable which means we cant DELETE tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1[0] =1 #Tuples are immutable which means we cant CHANGE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 t1[0] =1
#
# TypeError: 'tuple' object does not support item assignment

# %%
del t1  #Deleting whole Tuple is possible

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %% [markdown]
# ######LOOP THROUGH A TUPLE

# %%
t1=(10, True, 2.3, 1+2j, 'welcome')
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
for e in t1:
    print(e)
# Out:
# 10
# True
# 2.3
# (1+2j)
# welcome

# %%
for e in enumerate(t1):
    print(e)
# Out:
# (0, 10)
# (1, True)
# (2, 2.3)
# (3, (1+2j))
# (4, 'welcome')

# %% [markdown]
# ######TUPLE MEMBERSHIP

# %%
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
10 in t1  #Check if 10 exist in tuple
# Out:
# True

# %%
2.5 in t1  #Check if 2.5 exist in tuple
# Out:
# False

# %%
if 10 in t1:     #Check if 10 exist in the list
    print('10 is present in tuple')
else: 
    print('10 is not presemt in tuple')
# Out:
# 10 is present in tuple

# %%
if 'madhu' in t1:     #Check if madhu exist in the list
    print('madhu is present in tuple')
else: 
    print('madhu is not presemt in tuple')
# Out:
# madhu is not presemt in tuple

# %% [markdown]
# #####INDEX POSITION

# %%
t1
# Out:
# (10, True, 2.3, (1+2j), 'welcome')

# %%
t1.index(10)  #Index of first  element equal to one
# Out:
# 0

# %%
t1.index('welcome') #Index of first  element equal to one
# Out:
# 4

# %% [markdown]
# #####SORTING

# %%
t = (25,10,3,100,60,200)
t
# Out:
# (25, 10, 3, 100, 60, 200)

# %%
sorted (t)  #returns a new sorted list and doesnt change original tuple
# Out:
# [3, 10, 25, 60, 100, 200]

# %%
sorted (t, reverse =True) #sort in descending order
# Out:
# [200, 100, 60, 25, 10, 3]
